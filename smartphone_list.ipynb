# %%
import json
import csv
from pprint import pprint
file = open('aux.json')
json_data = json.load(file)

# %%
json_data
# Out:
# {u'data': [{u'brandEntity': {u'accountId': 7,
#     u'brandDesc': u'AUX',
#     u'brandLogoLoc': None,
#     u'brandName': u'AUX',
#     u'brandNationality': None,
#     u'createdDate': u'2018-12-03T09:50:05.000+0000',
#     u'displayInSmaartChat': u'N',
#     u'id': 270,
#     u'modifiedDate': u'2018-12-12T13:54:37.000+0000',
#     u'status': u'A'},
#    u'categoryEntity': {u'categoryDesc': u'Air Conditioners',
#     u'categoryIconLoc': None,
#     u'categoryName': u'Air Conditioners',
#     u'createdDate': u'2018-12-03T09:46:33.000+0000',
#     u'domainId': 1,
#     u'id': 4,
#     u'modifiedDate': u'2018-12-26T11:17:45.000+0000',
#     u'status': u'A'},
#    u'createdDate': u'2018-12-26T11:25:39.000+0000',
#    u'modifiedDate': u'2018-12-26T11:25:39.000+0000',
#    u'primaryImageLoc': u'300614/AUX-1-Ton-3-Star-ASW-123-NR-White-Split-AC-1.jpeg',
#    u'productId': 300614,
#    u'productName': u'AUX 1 Ton 3 Star ASW 123-NR White Split AC',
#    u'productType': u'Air Conditioner',
#    u'status': u'A'},
#   {u'brandEntity': {u'accountId': 7,
#     u'brandDesc': u'AUX',
#     u'brandLogoLoc': None,
#     u'brandName': u'AUX',
#     u'brandNationality': None,
#     u'createdDate': u'2018-12-03T09:50:05.000+0000',
#     u'displayInSmaartChat': u'N',
#     u'id': 270,
#     u'modifiedDate': u'2018-12-12T13:54:37.000+0000',
#     u'status': u'A'},
#    u'categoryEntity': {u'categoryDesc': u'Air Conditioners',
#     u'categoryIconLoc': None,
#     u'categoryName': u'Air Conditioners',
#     u'createdDate': u'2018-12-03T09:46:33.000+0000',
#     u'domainId': 1,
#     u'id': 4,
#     u'modifiedDate': u'2018-12-26T11:17:45.000+0000',
#     u'status': u'A'},
#    u'createdDate': u'2018-12-26T11:25:39.000+0000',
#    u'modifiedDate': u'2018-12-26T11:25:39.000+0000',
#    u'primaryImageLoc': u'300615/AUX-1-Ton-5-Star-ASW-125-LH-White-Split-AC-1.jpeg',
#    u'productId': 300615,
#    u'productName': u'AUX 1 Ton 5 Star ASW 125-LH White Split AC',
#    u'productType': u'Air Conditioner',
#    u'status': u'A'},
#   {u'brandEntity': {u'accountId': 7,
#     u'brandDesc': u'AUX',
#     u'brandLogoLoc': None,
#     u'brandName': u'AUX',
#     u'brandNationality': None,
#     u'createdDate': u'2018-12-03T09:50:05.000+0000',
#     u'displayInSmaartChat': u'N',
#     u'id': 270,
#     u'modifiedDate': u'2018-12-12T13:54:37.000+0000',
#     u'status': u'A'},
#    u'categoryEntity': {u'categoryDesc': u'Air Conditioners',
#     u'categoryIconLoc': None,
#     u'categoryName': u'Air Conditioners',
#     u'createdDate': u'2018-12-03T09:46:33.000+0000',
#     u'domainId': 1,
#     u'id': 4,
#     u'modifiedDate': u'2018-12-26T11:17:45.000+0000',
#     u'status': u'A'},
#    u'createdDate': u'2018-12-26T11:25:39.000+0000',
#    u'modifiedDate': u'2018-12-26T11:25:39.000+0000',
#    u'primaryImageLoc': u'300616/AUX-1.2-Ton-Inverter-ASW-12INV-LMS-Grey-Split-AC-1.jpeg',
#    u'productId': 300616,
#    u'productName': u'AUX 1.2 Ton Inverter ASW 12INV-LMS Grey Split AC',
#    u'productType': u'Air Conditioner',
#    u'status': u'A'},
#   {u'brandEntity': {u'accountId': 7,
#     u'brandDesc': u'AUX',
#     u'brandLogoLoc': None,
#     u'brandName': u'AUX',
#     u'brandNationality': None,
#     u'createdDate': u'2018-12-03T09:50:05.000+0000',
#     u'displayInSmaartChat': u'N',
#     u'id': 270,
#     u'modifiedDate': u'2018-12-12T13:54:37.000+0000',
#     u'status': u'A'},
#    u'categoryEntity': {u'categoryDesc': u'Air Conditioners',
#     u'categoryIconLoc': None,
#     u'categoryName': u'Air Conditioners',
#     u'createdDate': u'2018-12-03T09:46:33.000+0000',
#     u'domainId': 1,
#     u'id': 4,
#     u'modifiedDate': u'2018-12-26T11:17:45.000+0000',
#     u'status': u'A'},
#    u'createdDate': u'2018-12-26T11:25:39.000+0000',
#    u'modifiedDate': u'2018-12-26T11:25:39.000+0000',
#    u'primaryImageLoc': u'300617/AUX-1.3-Ton-Inverter-ASW-12INV-LVS-Grey-Split-AC-1.jpeg',
#    u'productId': 300617,
#    u'productName': u'AUX 1.3 Ton Inverter ASW 12INV-LVS Grey Split AC',
#    u'productType': u'Air Conditioner',
#    u'status': u'A'},
#   {u'brandEntity': {u'accountId': 7,
#     u'brandDesc': u'AUX',
#     u'brandLogoLoc': None,
#     u'brandName': u'AUX',
#     u'brandNationality': None,
#     u'createdDate': u'2018-12-03T09:50:05.000+0000',
#     u'displayInSmaartChat': u'N',
#     u'id': 270,
#     u'modifiedDate': u'2018-12-12T13:54:37.000+0000',
#     u'status': u'A'},
#    u'categoryEntity': {u'categoryDesc': u'Air Conditioners',
#     u'categoryIconLoc': None,
#     u'categoryName': u'Air Conditioners',
#     u'createdDate': u'2018-12-03T09:46:33.000+0000',
#     u'domainId': 1,
#     u'id': 4,
#     u'modifiedDate': u'2018-12-26T11:17:45.000+0000',
#     u'status': u'A'},
#    u'createdDate': u'2018-12-26T11:25:39.000+0000',
#    u'modifiedDate': u'2018-12-26T11:25:39.000+0000',
#    u'primaryImageLoc': u'300618/AUX-1.6-Ton-3-Star-ASW-183-NR-White-Split-AC-1.jpeg',
#    u'productId': 300618,
#    u'productName': u'AUX 1.6 Ton 3 Star ASW 183-NR White Split AC',
#    u'productType': u'Air Conditioner',
#    u'status': u'A'},
#   {u'brandEntity': {u'accountId': 7,
#     u'brandDesc': u'AUX',
#     u'brandLogoLoc': None,
#     u'brandName': u'AUX',
#     u'brandNationality': None,
#     u'createdDate': u'2018-12-03T09:50:05.000+0000',
#     u'displayInSmaartChat': u'N',
#     u'id': 270,
#     u'modifiedDate': u'2018-12-12T13:54:37.000+0000',
#     u'status': u'A'},
#    u'categoryEntity': {u'categoryDesc': u'Air Conditioners',
#     u'categoryIconLoc': None,
#     u'categoryName': u'Air Conditioners',
#     u'createdDate': u'2018-12-03T09:46:33.000+0000',
#     u'domainId': 1,
#     u'id': 4,
#     u'modifiedDate': u'2018-12-26T11:17:45.000+0000',
#     u'status': u'A'},
#    u'createdDate': u'2018-12-26T11:25:39.000+0000',
#    u'modifiedDate': u'2018-12-26T11:25:39.000+0000',
#    u'primaryImageLoc': u'300619/AUX-1.6-Ton-5-Star-ASW-185-LH-White-Split-AC-1.jpeg',
#    u'productId': 300619,
#    u'productName': u'AUX 1.6 Ton 5 Star ASW 185-LH White Split AC',
#    u'productType': u'Air Conditioner',
#    u'status': u'A'},
#   {u'brandEntity': {u'accountId': 7,
#     u'brandDesc': u'AUX',
#     u'brandLogoLoc': None,
#     u'brandName': u'AUX',
#     u'brandNationality': None,
#     u'createdDate': u'2018-12-03T09:50:05.000+0000',
#     u'displayInSmaartChat': u'N',
#     u'id': 270,
#     u'modifiedDate': u'2018-12-12T13:54:37.000+0000',
#     u'status': u'A'},
#    u'categoryEntity': {u'categoryDesc': u'Air Conditioners',
#     u'categoryIconLoc': None,
#     u'categoryName': u'Air Conditioners',
#     u'createdDate': u'2018-12-03T09:46:33.000+0000',
#     u'domainId': 1,
#     u'id': 4,
#     u'modifiedDate': u'2018-12-26T11:17:45.000+0000',
#     u'status': u'A'},
#    u'createdDate': u'2018-12-26T11:25:39.000+0000',
#    u'modifiedDate': u'2018-12-26T11:25:39.000+0000',
#    u'primaryImageLoc': u'300620/AUX-1.6-Ton-Inverter-ASW-18INV-LMS-Grey-Split-AC-1.jpeg',
#    u'productId': 300620,
#    u'productName': u'AUX 1.6 Ton Inverter ASW 18INV-LMS Grey Split AC',
#    u'productType': u'Air Conditioner',
#    u'status': u'A'},
#   {u'brandEntity': {u'accountId': 7,
#     u'brandDesc': u'AUX',
#     u'brandLogoLoc': None,
#     u'brandName': u'AUX',
#     u'brandNationality': None,
#     u'createdDate': u'2018-12-03T09:50:05.000+0000',
#     u'displayInSmaartChat': u'N',
#     u'id': 270,
#     u'modifiedDate': u'2018-12-12T13:54:37.000+0000',
#     u'status': u'A'},
#    u'categoryEntity': {u'categoryDesc': u'Air Conditioners',
#     u'categoryIconLoc': None,
#     u'categoryName': u'Air Conditioners',
#     u'createdDate': u'2018-12-03T09:46:33.000+0000',
#     u'domainId': 1,
#     u'id': 4,
#     u'modifiedDate': u'2018-12-26T11:17:45.000+0000',
#     u'status': u'A'},
#    u'createdDate': u'2018-12-26T11:25:39.000+0000',
#    u'modifiedDate': u'2018-12-26T11:25:39.000+0000',
#    u'primaryImageLoc': u'300621/AUX-1.6-Ton-Inverter-AC-ASW-18INV-LMS-AC-Silver-1.jpeg',
#    u'productId': 300621,
#    u'productName': u'AUX 1.6 Ton Inverter AC ASW 18INV-LMS AC Silver',
#    u'productType': u'Air Conditioner',
#    u'status': u'A'},
#   {u'brandEntity': {u'accountId': 7,
#     u'brandDesc': u'AUX',
#     u'brandLogoLoc': None,
#     u'brandName': u'AUX',
#     u'brandNationality': None,
#     u'createdDate': u'2018-12-03T09:50:05.000+0000',
#     u'displayInSmaartChat': u'N',
#     u'id': 270,
#     u'modifiedDate': u'2018-12-12T13:54:37.000+0000',
#     u'status': u'A'},
#    u'categoryEntity': {u'categoryDesc': u'Air Conditioners',
#     u'categoryIconLoc': None,
#     u'categoryName': u'Air Conditioners',
#     u'createdDate': u'2018-12-03T09:46:33.000+0000',
#     u'domainId': 1,
#     u'id': 4,
#     u'modifiedDate': u'2018-12-26T11:17:45.000+0000',
#     u'status': u'A'},
#    u'createdDate': u'2018-12-26T11:25:39.000+0000',
#    u'modifiedDate': u'2018-12-26T11:25:39.000+0000',
#    u'primaryImageLoc': u'300622/AUX-2-Ton-4-Star-ASW-244-NR-White-Split-AC-1.jpeg',
#    u'productId': 300622,
#    u'productName': u'AUX 2 Ton 4 Star ASW 244-NR White Split AC',
#    u'productType': u'Air Conditioner',
#    u'status': u'A'},
#   {u'brandEntity': {u'accountId': 7,
#     u'brandDesc': u'AUX',
#     u'brandLogoLoc': None,
#     u'brandName': u'AUX',
#     u'brandNationality': None,
#     u'createdDate': u'2018-12-03T09:50:05.000+0000',
#     u'displayInSmaartChat': u'N',
#     u'id': 270,
#     u'modifiedDate': u'2018-12-12T13:54:37.000+0000',
#     u'status': u'A'},
#    u'categoryEntity': {u'categoryDesc': u'Air Conditioners',
#     u'categoryIconLoc': None,
#     u'categoryName': u'Air Conditioners',
#     u'createdDate': u'2018-12-03T09:46:33.000+0000',
#     u'domainId': 1,
#     u'id': 4,
#     u'modifiedDate': u'2018-12-26T11:17:45.000+0000',
#     u'status': u'A'},
#    u'createdDate': u'2018-12-26T11:25:39.000+0000',
#    u'modifiedDate': u'2018-12-26T11:25:39.000+0000',
#    u'primaryImageLoc': u'300623/AUX-2-Ton-5-Star-ASW-245-LH-White-Split-AC-1.jpeg',
#    u'productId': 300623,
#    u'productName': u'AUX 2 Ton 5 Star ASW 245-LH White Split AC',
#    u'productType': u'Air Conditioner',
#    u'status': u'A'},
#   {u'brandEntity': {u'accountId': 7,
#     u'brandDesc': u'AUX',
#     u'brandLogoLoc': None,
#     u'brandName': u'AUX',
#     u'brandNationality': None,
#     u'createdDate': u'2018-12-03T09:50:05.000+0000',
#     u'displayInSmaartChat': u'N',
#     u'id': 270,
#     u'modifiedDate': u'2018-12-12T13:54:37.000+0000',
#     u'status': u'A'},
#    u'categoryEntity': {u'categoryDesc': u'Air Conditioners',
#     u'categoryIconLoc': None,
#     u'categoryName': u'Air Conditioners',
#     u'createdDate': u'2018-12-03T09:46:33.000+0000',
#     u'domainId': 1,
#     u'id': 4,
#     u'modifiedDate': u'2018-12-26T11:17:45.000+0000',
#     u'status': u'A'},
#    u'createdDate': u'2018-12-26T11:25:39.000+0000',
#    u'modifiedDate': u'2018-12-26T11:25:39.000+0000',
#    u'primaryImageLoc': u'300624/AUX-2.2-Ton-Inverter-ASW-24INV-LMS-Grey-Split-AC-1.jpeg',
#    u'productId': 300624,
#    u'productName': u'AUX 2.2 Ton Inverter ASW 24INV-LMS Grey Split AC',
#    u'productType': u'Air Conditioner',
#    u'status': u'A'}],
#  u'error': None,
#  u'remarks': u'',
#  u'sessionValid': True}

# %%
print json_data.keys()
# Out:
# [u'remarks', u'data', u'sessionValid', u'error']

# %%
for z in range(0,10):
    xxx=json_data['data'][z]['productName']
    #count=count+1
    #print count
    print xxx
# Out:
# AUX 1 Ton 3 Star ASW 123-NR White Split AC
# AUX 1 Ton 5 Star ASW 125-LH White Split AC
# AUX 1.2 Ton Inverter ASW 12INV-LMS Grey Split AC
# AUX 1.3 Ton Inverter ASW 12INV-LVS Grey Split AC
# AUX 1.6 Ton 3 Star ASW 183-NR White Split AC
# AUX 1.6 Ton 5 Star ASW 185-LH White Split AC
# AUX 1.6 Ton Inverter ASW 18INV-LMS Grey Split AC
# AUX 1.6 Ton Inverter AC ASW 18INV-LMS AC Silver
# AUX 2 Ton 4 Star ASW 244-NR White Split AC
# AUX 2 Ton 5 Star ASW 245-LH White Split AC

# %%
yyy=xxx.split(',')

# %%
print yyy
# Out:
# [u'AUX 2 Ton 5 Star ASW 245-LH White Split AC']

# %%
for z in range(0,10):
    xxx=json_data['data'][z]['productId']
    #count=count+1
    #print count
    print xxx
# Out:
# 300614
# 300615
# 300616
# 300617
# 300618
# 300619
# 300620
# 300621
# 300622
# 300623

# %%
##############_Samsung_#########

# %%
import json
import csv
from pprint import pprint
file = open('samsung.json')
json_data = json.load(file)
