# %%
import urllib, json
url = "https://api.bazaarvoice.com/data/batch.json?passkey=caGz3Lh4mJONU0X59qHTQJCG7XsK4b37wJcZLfsOcz8gE&apiversion=5.5&displaycode=20554-en_in&resource.q1=reviews&filter.q1=isratingsonly%3Aeq%3Afalse&filter.q1=productid%3Aeq%3ASM-N960FZBDINS&stats.q1=reviews&filteredstats.q1=reviews&include.q1=authors%2Cproducts%2Ccomments&limit.q1=80"
response = urllib.urlopen(url)
data = json.loads(response.read())
#r = request.get(url,)
print data
# Out:
# {u'BatchedResultsOrder': [u'q1'], u'Errors': [], u'HasErrors': False, u'BatchedResults': {u'q1': {u'Errors': [], u'HasErrors': False, u'Locale': u'en_IN', u'Results': [{u'TotalPositiveFeedbackCount': 0, u'CID': u'3635c231-a7df-5dbe-9a01-42c2cbe532d9', u'CommentIds': [], u'TotalClientResponseCount': 0, u'Pros': None, u'UserLocation': None, u'LastModeratedTime': u'2018-12-18T01:00:02.000+00:00', u'SourceClient': u'samsung-en_in', u'TagDimensionsOrder': [u'Pro', u'Con'], u'Title': u'Better than apple xs max', u'TotalFeedbackCount': 0, u'BadgesOrder': [], u'IsSyndicated': False, u'ContextDataValuesOrder': [], u'CampaignId': u'BV_RATING_SUMMARY', u'AdditionalFields': {}, u'LastModificationTime': u'2018-12-18T01:00:02.000+00:00', u'SubmissionId': u'2ana2iemsa2n9b34racl9j4bf', u'Photos': [], u'TagDimensions': {u'Pro': {u'Values': [u'Inexpensive', u'Realistic color', u'Bright display', u'Lightweight', u'Built-in speakers', u'Durable'], u'Id': u'Pro', u'Label': None}, u'Con': {u'Values': [u'T
# ...

# %%
print data.keys()
# Out:
# [u'BatchedResultsOrder', u'Errors', u'HasErrors', u'BatchedResults', u'TotalRequests', u'SuccessfulRequests', u'FailedRequests']

# %%
#data['BatchedResults']['q1']['Results'][0]['ReviewText']

# %%
#data['BatchedResults']['q1']['Results'][21]['ReviewText']

# %%
#for z in range(0,24):
    #print  data['BatchedResults']['q1']['Results'][z]['ReviewText'].split('\t')

# %%
##########Review_Text####################

# %%
count=0

# %%
for z in range(0,24):
    xxx=data['BatchedResults']['q1']['Results'][z]['ReviewText']
    count=count+1
    print count
    print xxx
# Out:
# 25
# Good but it was not able to use in single hand operation due to it size
# Other ways it next generation smartphone
# 26
# I bought this pjone a month ago, I was so very excited to use the phone, unfortunately it was not working properly, At the servivr centre they told me that it had some issues with manufacturing and was a natural defect in the product. But thanks to Samsung they replaced whole of the phone's components from within. And now its working awsome...
# 27
# The good The Samsung Galaxy Note 9 is a big, beautiful phone with top-tier specs including a massive battery and internal storage
# But the Note 9 is no more toy. It's also powerful with a 6.4-inch screen, 4,000-mAh battery, Qualcomm Snapdragon 845 processor and either 128GB or a whopping 512GB of onboard storage, plus a microSD card if you want more, more, more.
# The Galaxy Note 9's specs are top-notch. This is an everything phone, one of the absolute best you can buy with All The Things.
# 28
# ...

# %%
with open('csvfile.csv','w') as file:
    for l in xxx:
        file.write(l)
        file.write('\n')

# %%
#############Title###############

# %%
count=0

# %%
for z in range(0,24):
    YYY=data['BatchedResults']['q1']['Results'][z]['Title']
    count=count+1
    #print count
    print YYY
# Out:
# Better than apple xs max
# Got some technical issues with mine
# The greatest note ever like all rounder
# "Great" is an understatement. It's perfection!
# Great display
# Battry,camera,screen,all above spen
# Overall satisfaction experience
# Great features and performance!
# The Perfect Android Phone.
# Superb and most powerful mobile in today market
# Great note
# It's amaz.. phone dude.
# Awesome
# S pen
# Excellent device
# Legendary
# Front camera
# Whatsapp status uploading error in note9
# I love my note 9
# Just a great phone
# GREAT PHONE
# Awesome
# greatphone
# World's best phone till date...

# %%
YYY = open('test.csv', 'r')
w = csv.writer(YYY)

for l in YYY:
    w.writerow(l)
    YYY.close()

# %%
##############UserNickname#####################

# %%
count=0

# %%
for z in range(0,24):
    PPP=data['BatchedResults']['q1']['Results'][z]['UserNickname']
    count=count+1
    #print count
    print PPP
# Out:
# Sid s
# shiv6044
# None
# Zayan
# Amit8009
# Maddy
# srdsachin
# Singhtech
# None
# Mr Verma
# gaurav
# Sidhu
# ARAV
# Azzu
# Sunny
# js karthik
# Debu
# Shweta verma
# Naveen3
# thebuyer
# Rajdeep
# UTKARSH
# sammy fan
# Chandan

# %%
############Product_ID_##################

# %%
count=0

# %%
for z in range(0,24):
    Product_Id=data['BatchedResults']['q1']['Results'][z]['ProductId']
    #print count
    print Product_Id
# Out:
# SM-N960FZKDINS
# SM-N960FZBDINS
# SM-N960FZBDINS
# SM-N960FZBDINS
# SM-N960FZPDINS
# SM-N960FZPDINS
# SM-N960FZBDINS
# SM-N960FZBDINS
# SM-N960FZBDINS
# SM-N960FZBDINS
# SM-N960FZBDINS
# SM-N960FZPDINS
# SM-N960FZBDINS
# SM-N960FZBDINS
# SM-N960FZBDINS
# SM-N960FZBDINS
# SM-N960FZBDINS
# SM-N960FZBDINS
# SM-N960FZBDINS
# SM-N960FZBDINS
# SM-N960FZBDINS
# SM-N960FZBDINS
# SM-N960FZBDINS
# SM-N960FZBDINS

# %%
############Star_Ratings_##################

# %%
for z in range(0,24):
    Product_Id=data['BatchedResults']['q1']['Results'][z]['Rating']
    #print count
    print Product_Id
# Out:
# 5
# 4
# 5
# 5
# 5
# 4
# 5
# 5
# 5
# 5
# 4
# 5
# 4
# 5
# 5
# 5
# 4
# 1
# 5
# 5
# 5
# 5
# 5
# 5

# %%
################_Submission_Time__#################

# %%
for z in range(0,24):
    Product_Id=data['BatchedResults']['q1']['Results'][z]['SubmissionTime']
    #print count
    print Product_Id
# Out:
# 2018-12-17T14:47:44.000+00:00
# 2018-11-29T10:24:07.000+00:00
# 2018-11-28T17:20:47.000+00:00
# 2018-11-27T05:27:54.000+00:00
# 2018-11-25T05:26:18.000+00:00
# 2018-11-20T07:38:04.000+00:00
# 2018-11-15T16:24:49.000+00:00
# 2018-11-15T04:31:00.000+00:00
# 2018-11-07T09:33:33.000+00:00
# 2018-11-03T13:47:54.000+00:00
# 2018-11-02T09:15:17.000+00:00
# 2018-10-29T14:10:44.000+00:00
# 2018-10-25T00:58:01.000+00:00
# 2018-10-24T19:35:58.000+00:00
# 2018-10-24T17:43:58.000+00:00
# 2018-10-18T15:01:29.000+00:00
# 2018-10-18T08:07:51.000+00:00
# 2018-10-16T11:44:58.000+00:00
# 2018-10-14T07:13:50.000+00:00
# 2018-10-07T09:16:45.000+00:00
# 2018-09-14T00:40:18.000+00:00
# 2018-09-13T07:46:36.000+00:00
# 2018-09-06T17:35:42.000+00:00
# 2018-08-30T22:18:10.000+00:00
