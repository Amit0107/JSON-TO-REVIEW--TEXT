# %%
import json
import csv
from pprint import pprint
file = open('smartphone.json')
json_data = json.load(file)

# %%
json_data
# Out:
# {u'BatchedResults': {u'q0': {u'Errors': [],
#    u'HasErrors': False,
#    u'Id': u'q0',
#    u'Includes': {},
#    u'Limit': 10,
#    u'Locale': u'en_IN',
#    u'Offset': 0,
#    u'Results': [{u'Active': True,
#      u'Attributes': {u'BV_FE_EXPAND': {u'Id': u'BV_FE_EXPAND',
#        u'Values': [{u'Locale': None, u'Value': u'BV_FE_FAMILY:SM-J610F_DS'}]},
#       u'BV_FE_FAMILY': {u'Id': u'BV_FE_FAMILY',
#        u'Values': [{u'Locale': None, u'Value': u'SM-J610F_DS'}]}},
#      u'AttributesOrder': [u'BV_FE_EXPAND', u'BV_FE_FAMILY'],
#      u'Brand': {u'Id': u'samsung', u'Name': u'samsung'},
#      u'BrandExternalId': u'samsung',
#      u'CategoryId': u'20010500',
#      u'Description': None,
#      u'Disabled': False,
#      u'EANs': [u'8801643499334', u'8801643555634', u'8801643499112'],
#      u'FamilyIds': [u'SM-J610F_DS'],
#      u'FilteredReviewStatistics': {u'AverageOverallRating': 3.4,
#       u'ContextDataDistribution': {},
#       u'ContextDataDistributionOrder': [],
# ...

# %%
print json_data.keys()
# Out:
# [u'BatchedResultsOrder', u'Errors', u'HasErrors', u'BatchedResults', u'TotalRequests', u'SuccessfulRequests', u'FailedRequests']

# %%
b=open('reviewtext.csv','w')
a=csv.writer(b)
data=['Review-Text','Title','Price','UserNickname','ProductId','SubmissionTime','Rating']
a.writerows(data)

# %%
count=0

# %%
####Review_Text_########

# %%
for z in range(0,100):
    xxx=json_data['BatchedResults']['q1']['Results'][z]['ReviewText']
    count=count+1
    print count
    print xxx
# Out:
# 41
# Great smart phone at great pricing. All  should buy
# 42
# I bought 2days back it's awesome performance and very nice looking
# 43
# ITS A GOOD ONE BETTER THAN J8 ..NOT HEAT AT ALL.SMOOTH N FAST N LOOKS IS GOOD ..CHARGING FAST N MORE DURATION...OVERALL A GOOD CHOICE,,I AM CONFUSE THAT WHY SAMSUNG HAS LAUNCHED THIS ONE IN SUCH A LESS PRICE..SIZE IS LITTLE BIGGER THAN SAMSUNG J8..GOOD ONE
# 44
# Comparing with other phones of this range, Samsung J6 plus is the best one.
# That's what I did and purchased. New features, stunning look, glossy finish, low price, AMOLED screen and camera technology made it a must buy product. Hope Samsung will serve us with these kind a products always. Lovin' it ♥
# 45
# Plz increase the battery capacity as like Asus mob.
# Except battery problem this product is so good
# 46
# I buy 20 day before I'm not satisfied mobile very high price
# 47
# There must be Lock screen Stories just like as in J6.
# 48
# ...

# %%
###_Title_####

# %%
for z in range(0,100):
    YYY=json_data['BatchedResults']['q1']['Results'][z]['Title']
    count=count+1
    #print count
    print YYY
# Out:
# Great smart phone at great pricing
# Side fingerprint, looking
# VERY SMOOTH N FAST NOT GETS HEAT
# J6 plus is a gift from Samsung
# Great features but lacking of battery capacity
# Battery draining
# Lock Screen Stories missed
# Best but not better
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-74-623d0a0ebce5> in <module>()
#       1 for z in range(0,100):
# ----> 2     YYY=json_data['BatchedResults']['q1']['Results'][z]['Title']
#       3     count=count+1
#       4     #print count
#       5     print YYY
#
# IndexError: list index out of range

# %%
####____UserNickname____######

# %%
for z in range(0,100):
    PPP=json_data['BatchedResults']['q1']['Results'][z]['UserNickname']
    count=count+1
    #print count
    print PPP
# Out:
# Vishnu
# None
# SAGAR
# Cris
# Roshni
# Ganeshmani
# None
# Ravi4725
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-83-0e7b3614daf3> in <module>()
#       1 for z in range(0,100):
# ----> 2     PPP=json_data['BatchedResults']['q1']['Results'][z]['UserNickname']
#       3     count=count+1
#       4     #print count
#       5     print PPP
#
# IndexError: list index out of range

# %%
#####_Product_ID__####

# %%
for z in range(0,100):
    Product_Id=json_data['BatchedResults']['q1']['Results'][z]['ProductId']
    #print count
    print Product_Id
# Out:
# SM-J610FZRGINS
# SM-J610FZBGINS
# SM-J610FZKGINS
# SM-J610FZKGINS
# SM-J610FZRGINS
# SM-J610FZRGINS
# SM-J610FZKGINS
# SM-J610FZRGINS
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-78-5f1004846775> in <module>()
#       1 for z in range(0,100):
# ----> 2     Product_Id=json_data['BatchedResults']['q1']['Results'][z]['ProductId']
#       3     #print count
#       4     print Product_Id
#
# IndexError: list index out of range

# %%
####__SubmissionTime___####

# %%
for z in range(0,100):
    Submission_Time=json_data['BatchedResults']['q1']['Results'][z]['SubmissionTime']
    #print count
    print Submission_Time
# Out:
# 2018-10-09T05:56:58.000+00:00
# 2018-10-03T10:51:11.000+00:00
# 2018-10-03T05:50:52.000+00:00
# 2018-09-30T06:12:21.000+00:00
# 2018-11-02T15:38:53.000+00:00
# 2018-11-05T13:00:11.000+00:00
# 2018-10-05T05:00:43.000+00:00
# 2018-12-10T03:19:54.000+00:00
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-84-13ddeaf8c4f0> in <module>()
#       1 for z in range(0,100):
# ----> 2     Submission_Time=json_data['BatchedResults']['q1']['Results'][z]['SubmissionTime']
#       3     #print count
#       4     print Submission_Time
#
# IndexError: list index out of range

# %%
#####_Rating_#####

# %%
for z in range(0,100):
    Rating=json_data['BatchedResults']['q1']['Results'][z]['Rating']
    #print count
    print Rating
# Out:
# 5
# 5
# 5
# 5
# 4
# 3
# 3
# 2
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-82-e9b379b21c9c> in <module>()
#       1 for z in range(0,100):
# ----> 2     Rating=json_data['BatchedResults']['q1']['Results'][z]['Rating']
#       3     #print count
#       4     print Rating
#
# IndexError: list index out of range

# %%
 a.writerows([[xxx.text, YYY.text, PPP.text,Product_Id.text,Submission_Time.text,Rating.text]])
b.close()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-44-c8ff682c52da> in <module>()
# ----> 1 a.writerows([[xxx.text, YYY.text, PPP.text,Product_Id.text,Submission_Time.text,Rating.text]])
#       2 b.close()
#
# AttributeError: 'unicode' object has no attribute 'text'
