# %%
import json
from pprint import pprint
file = open('refi.json')
json_data = json.load(file)

# %%
json_data
# Out:
# {u'BatchedResults': {u'q0': {u'Errors': [],
#    u'HasErrors': False,
#    u'Id': u'q0',
#    u'Includes': {},
#    u'Limit': 10,
#    u'Locale': u'en_IN',
#    u'Offset': 0,
#    u'Results': [{u'Active': True,
#      u'Attributes': {u'BV_FE_EXPAND': {u'Id': u'BV_FE_EXPAND',
#        u'Values': [{u'Locale': None, u'Value': u'BV_FE_FAMILY:RH62K60B77P'}]},
#       u'BV_FE_FAMILY': {u'Id': u'BV_FE_FAMILY',
#        u'Values': [{u'Locale': None, u'Value': u'RH62K60B77P'}]}},
#      u'AttributesOrder': [u'BV_FE_EXPAND', u'BV_FE_FAMILY'],
#      u'Brand': {u'Id': u'samsung', u'Name': u'samsung'},
#      u'BrandExternalId': u'samsung',
#      u'CategoryId': u'25020200',
#      u'Description': None,
#      u'Disabled': False,
#      u'EANs': [u'8801643168704'],
#      u'FamilyIds': [u'RH62K60B77P'],
#      u'FilteredReviewStatistics': {u'AverageOverallRating': 5,
#       u'ContextDataDistribution': {},
#       u'ContextDataDistributionOrder': [],
#       u'FeaturedReviewCount': 0,
# ...

# %%
print json_data.keys()
# Out:
# [u'BatchedResultsOrder', u'Errors', u'HasErrors', u'BatchedResults', u'TotalRequests', u'SuccessfulRequests', u'FailedRequests']

# %%
count=0

# %%
####Review_Text_########

# %%
for z in range(0,100):
    xxx=json_data['BatchedResults']['q1']['Results'][z]['ReviewText']
    count=count+1
    print count
    print xxx
# Out:
# 1
# very excelant Samsung ref new modals in door by door
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-100-ce5541ef4d1f> in <module>()
#       1 for z in range(0,100):
# ----> 2     xxx=json_data['BatchedResults']['q1']['Results'][z]['ReviewText']
#       3     count=count+1
#       4     print count
#       5     print xxx
#
# IndexError: list index out of range

# %%
for z in range(0,24):
    YYY=json_data['BatchedResults']['q1']['Results'][z]['Title']
    count=count+1
    #print count
    print YYY
# Out:
# Ref
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-101-1be585a45f85> in <module>()
#       1 for z in range(0,24):
# ----> 2     YYY=json_data['BatchedResults']['q1']['Results'][z]['Title']
#       3     count=count+1
#       4     #print count
#       5     print YYY
#
# IndexError: list index out of range

# %%
for z in range(0,24):
    PPP=json_data['BatchedResults']['q1']['Results'][z]['UserNickname']
    count=count+1
    #print count
    print PPP
# Out:
# GggG
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-102-6c93b59f804d> in <module>()
#       1 for z in range(0,24):
# ----> 2     PPP=json_data['BatchedResults']['q1']['Results'][z]['UserNickname']
#       3     count=count+1
#       4     #print count
#       5     print PPP
#
# IndexError: list index out of range

# %%
for z in range(0,24):
    Product_Id=json_data['BatchedResults']['q1']['Results'][z]['ProductId']
    #print count
    print Product_Id
# Out:
# RH62K60B77P_TL
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-103-cb174ee4afb7> in <module>()
#       1 for z in range(0,24):
# ----> 2     Product_Id=json_data['BatchedResults']['q1']['Results'][z]['ProductId']
#       3     #print count
#       4     print Product_Id
#
# IndexError: list index out of range

# %%
for z in range(0,24):
    Product_Id=json_data['BatchedResults']['q1']['Results'][z]['SubmissionTime']
    #print count
    print Product_Id
# Out:
# 2018-07-14T04:39:38.000+00:00
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-104-67cb77c779c0> in <module>()
#       1 for z in range(0,24):
# ----> 2     Product_Id=json_data['BatchedResults']['q1']['Results'][z]['SubmissionTime']
#       3     #print count
#       4     print Product_Id
#
# IndexError: list index out of range

# %%
for z in range(0,24):
    Product_Id=json_data['BatchedResults']['q1']['Results'][z]['Rating']
    #print count
    print Product_Id
# Out:
# 5
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-105-454a5acf8347> in <module>()
#       1 for z in range(0,24):
# ----> 2     Product_Id=json_data['BatchedResults']['q1']['Results'][z]['Rating']
#       3     #print count
#       4     print Product_Id
#
# IndexError: list index out of range
